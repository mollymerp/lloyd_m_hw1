# %% [markdown]
# # Homework 1. Exploratory Data Analysis
#
# Due: Thursday, September 18, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW1.ipynb download=HW1.ipynb> Download this assignment</a>
#
# ---

# %% [markdown]
# ## Introduction
#
# In this homework we ask you three questions that we expect you to answer using data. For each question we ask you to complete a series of tasks that should help guide you through the data analysis. Complete these tasks and then write a short (100 words or less) answer to the question.
#
# **Note**: We will briefly discuss this homework assignment on Thursday in class.
#
# #### Data
# For this assignment we will use two databases:
#
# 1. The [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) which contains the "complete batting and pitching statistics from 1871 to 2013, plus fielding statistics, standings, team stats, managerial records, post-season data, and more. For more details on the latest release, please [read the documentation](http://seanlahman.com/files/database/readme2012.txt)."
#
# 2. [Gapminder](http://www.gapminder.org) is a great resource that contains over [500 data sets](http://www.gapminder.org/data/) related to world indicators such as income, GDP and life expectancy.
#
#
# #### Purpose
#
# In this assignment, you will learn how to:
#
# a. Load in CSV files from the web.
#
# b. Create functions in python.
#
# C. Create plots and summary statistics for exploratory data analysis such as histograms, boxplots and scatter plots.
#
#
# #### Useful libraries for this assignment
#
# * [numpy](http://docs.scipy.org/doc/numpy-dev/user/index.html), for arrays
# * [pandas](http://pandas.pydata.org/), for data frames
# * [matplotlib](http://matplotlib.org/), for plotting
#
# ---

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1
#
# In Lecture 1, we showed a plot that provided evidence that the 2002 and 2003 Oakland A's, a team that used data science, had a competitive advantage. Since, others teams have started using data science as well. Use exploratory data analysis to determine if the competitive advantage has since disappeared.

# %% [markdown]
# #### Problem 1(a)
# Load in [these CSV files](http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip) from the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics). For this assignment, we will use the 'Salaries.csv' and 'Teams.csv' tables. Read these tables into a pandas `DataFrame` and show the head of each table.
#
# **Hint** Use the [requests](http://docs.python-requests.org/en/latest/), [StringIO](http://docs.python.org/2/library/stringio.html) and [zipfile](https://docs.python.org/2/library/zipfile.html) modules to get from the web.

# %%
#your code here
import requests, zipfile, StringIO
zip_url = 'http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip'
r = requests.get(zip_url)
z = zipfile.ZipFile(StringIO.StringIO(r.content))

sal = z.read('Salaries.csv')
s_str = StringIO.StringIO(sal)
salaries = pd.read_csv(s_str)

t = z.read('Teams.csv')
t_str = StringIO.StringIO(t)
team = pd.read_csv(t_str)
teams = team.set_index(['teamID','yearID'])

salaries.head()
# Out:
#    yearID teamID lgID   playerID   salary
# 0    1985    BAL   AL  murraed02  1472819
# 1    1985    BAL   AL   lynnfr01  1090000
# 2    1985    BAL   AL  ripkeca01   800000
# 3    1985    BAL   AL   lacyle01   725000
# 4    1985    BAL   AL  flanami01   641667

# %%
teams.head()
# Out:
#               lgID franchID divID  Rank   G  Ghome   W   L DivWin WCWin  ...   \
# teamID yearID                                                            ...
# PH1    1871    NaN      PNA   NaN     1  28    NaN  21   7    NaN   NaN  ...
# CH1    1871    NaN      CNA   NaN     2  28    NaN  19   9    NaN   NaN  ...
# BS1    1871    NaN      BNA   NaN     3  31    NaN  20  10    NaN   NaN  ...
# WS3    1871    NaN      OLY   NaN     4  32    NaN  15  15    NaN   NaN  ...
# NY2    1871    NaN      NNA   NaN     5  33    NaN  16  17    NaN   NaN  ...
#
#                DP    FP                     name                      park  \
# teamID yearID
# PH1    1871   NaN  0.84   Philadelphia Athletics  Jefferson Street Grounds
# CH1    1871   NaN  0.82  Chicago White Stockings   Union Base-Ball Grounds
# BS1    1871   NaN  0.83     Boston Red Stockings       South End Grounds I
# WS3    1871   NaN  0.85      Washington Olympics          Olympics Grounds
# ...

# %% [markdown]
# #### Problem 1(b)
#
# Summarize the Salaries DataFrame to show the total salaries for each team for each year. Show the head of the new summarized DataFrame.

# %%
#your code here
sumSal = salaries.groupby(['teamID','yearID']).aggregate(np.sum)


#teams.set_index(['teamID','yearID'])
sumSal.head()
# Out:
#                  salary
# teamID yearID
# ANA    1997    31135472
#        1998    41281000
#        1999    55388166
#        2000    51464167
#        2001    47535167

# %% [markdown]
# #### Problem 1(c)
#
# Merge the new summarized Salaries DataFrame and Teams DataFrame together to create a new DataFrame
# showing wins and total salaries for each team for each year year. Show the head of the new merged DataFrame.
#
# **Hint**: Merge the DataFrames using `teamID` and `yearID`.

# %%
#your code here
team_cols = ['W']
sal_cols = ['yearID','teamID','salary']
teamSub = teams[team_cols]


winSalaries = sumSal.join(teamSub)
winSalaries.head()
# Out:
#                  salary   W
# teamID yearID
# ANA    1997    31135472  84
#        1998    41281000  85
#        1999    55388166  70
#        2000    51464167  82
#        2001    47535167  75

# %% [markdown]
# #### Problem 1(d)
#
# How would you graphically display the relationship between total wins and total salaries for a given year? What kind of plot would be best? Choose a plot to show this relationship and specifically annotate the Oakland baseball team on the on the plot. Show this plot across multiple years. In which years can you detect a competitive advantage from the Oakland baseball team of using data science? When did this end?
#
# **Hints**: Use a `for` loop to consider multiple years. Use the `teamID` (three letter representation of the team name) to save space on the plot.

# %%
winSalaries.reset_index(level=0, inplace=True)
winSalaries.reset_index(level=0, inplace=True)
#convert to millions
winSalaries['salary'] *= .000001
winSalaries.head()
# Out:
#    yearID teamID     salary   W
# 0    1997    ANA  31.135472  84
# 1    1998    ANA  41.281000  85
# 2    1999    ANA  55.388166  70
# 3    2000    ANA  51.464167  82
# 4    2001    ANA  47.535167  75

# %%
#your code here


def yearPlot(year):
    yearFrame = winSalaries[(winSalaries.yearID==year)]
    colors = np.where(yearFrame.teamID == 'OAK', 'g', 'w')
    scat = plt.scatter(yearFrame.salary, yearFrame.W, c=colors)
    plt.xlabel('Salary, $mil')
    plt.ylabel('Wins')
    plt.title(year)
    plt.show()

for years in [2000, 2002, 2005, 2010]:
    yearPlot(years)

# %% [markdown]
# #### Problem 1(e):
#
# **For AC209 Students**: Fit a linear regression to the data from each year and obtain the residuals. Plot the residuals against time to detect patterns that support your answer in 1(d).

# %%
#your code here
resid = []
def yearPlot(year):
    yearFrame = winSalaries[(winSalaries.yearID==year)]
    colors = np.where(yearFrame.teamID == 'OAK', 'g', 'w')
    scat = plt.scatter(yearFrame.salary, yearFrame.W, c=colors)
    m, b = np.polyfit(yearFrame.salary, yearFrame.W , 1)
    plt.plot(yearFrame.salary, m*yearFrame.salary + b)
    plt.xlabel('Salary, $mil')
    plt.ylabel('Wins')
    plt.title(year)
    plt.show()
    
def residualRange(year):
    yearFrame = winSalaries[(winSalaries.yearID==year)]
    m, b = np.polyfit(yearFrame.salary, yearFrame.W , 1)
    resid.append(np.polyfit(yearFrame.salary, yearFrame.W , 1,full=True)[1])

for years in range(1990,2012):
    residualRange(years)
    
for years in range(1996,2012,2):
    yearPlot(years)

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# A scatter plot is the best way to see the relationship between total salary payout and total wins across many teams.
#
# As you can tell from the plots above scatter plots with regression lines, the Oakland baseball team reached the peak comparative advantage in 2002, when the actual wins/salary (green dot) was furthest from the expected wins/salary ratio (blue line). This is further illustrated by the residuals plot below.

# %%
resid = pd.DataFrame(resid)
plt.plot(range(1990,2012),resid)
plt.title("Residuals")

# %% [markdown]
# ## Problem 2
#
# Several media reports have demonstrated the income inequality has increased in the US during this last decade. Here we will look at global data. Use exploratory data analysis to determine if the gap between Africa/Latin America/Asia and Europe/NorthAmerica has increased, decreased or stayed the same during the last two decades.

# %% [markdown]
# #### Problem 2(a)
#
# Using the list of countries by continent from [World Atlas](http://www.worldatlas.com/cntycont.htm) data, load in the `countries.csv` file into a pandas DataFrame and name this data set as `countries`.  This data set can be found on Github in the 2014_data repository [here](https://github.com/cs109/2014_data/blob/master/countries.csv).

# %%
#your code here
csv_url = 'https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv'
countries = pd.read_csv(csv_url)

countries.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# Using the [data available on Gapminder](http://www.gapminder.org/data/), load in the [Income per person (GDP/capita, PPP$ inflation-adjusted)](https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0) as a pandas DataFrame and name this data set as `income`.
#
# **Hint**: Consider using the pandas function `pandas.read_excel()` to read in the .xlsx file directly.

# %%
#your code here
import shutil
import urllib

xls_url = 'https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0&output=xls'

urllib.urlretrieve(xls_url, "gdpcap.xls")


inc = pd.read_excel('gdpcap.xls')
inc.rename(columns={'gdp pc test':'Country'}, inplace=True)
income = inc.set_index('Country')
income.head()
# Out:
#                              1800        1801        1802        1803  \
# Country
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            472.053500  472.053500  472.053500  472.053500
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                601.215222  601.839631  602.464688  603.090394
# Algeria                766.253664  766.234779  766.215895  766.197011
#
#                              1804        1805        1806        1807  \
# Country
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            472.053500  472.053500  472.053500  472.053500
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                603.716751  604.343757  604.971415  605.599725
# Algeria                766.178127  766.159244  766.140362  766.121480
#
#                              1808        1809     ...             2003  \
# ...

# %% [markdown]
# Transform the data set to have years as the rows and countries as the columns. Show the head of this data set when it is loaded.

# %%
#your code here
income = income.transpose()
income.head()
# Out:
# Country  Abkhazia  Afghanistan  Akrotiri and Dhekelia     Albania     Algeria  \
# 1800          NaN     472.0535                    NaN  601.215222  766.253664
# 1801          NaN     472.0535                    NaN  601.839631  766.234779
# 1802          NaN     472.0535                    NaN  602.464688  766.215895
# 1803          NaN     472.0535                    NaN  603.090394  766.197011
# 1804          NaN     472.0535                    NaN  603.716751  766.178127
#
# Country  American Samoa      Andorra      Angola    Anguilla  \
# 1800         674.453726  1260.123256  359.932582  775.668711
# 1801         674.453726  1262.214402  359.932582  775.668711
# 1802         674.453726  1264.309018  359.932582  775.668711
# 1803         674.453726  1266.407109  359.932582  775.668711
# 1804         674.453726  1268.508683  359.932582  775.668711
#
# Country  Antigua and Barbuda         ...           Western Sahara     Vietnam  \
# ...

# %%
income.reset_index(level=0, inplace=True)
income.head()
# Out:
# Country  index  Abkhazia  Afghanistan  Akrotiri and Dhekelia     Albania  \
# 0         1800       NaN     472.0535                    NaN  601.215222
# 1         1801       NaN     472.0535                    NaN  601.839631
# 2         1802       NaN     472.0535                    NaN  602.464688
# 3         1803       NaN     472.0535                    NaN  603.090394
# 4         1804       NaN     472.0535                    NaN  603.716751
#
# Country     Algeria  American Samoa      Andorra      Angola    Anguilla  \
# 0        766.253664      674.453726  1260.123256  359.932582  775.668711
# 1        766.234779      674.453726  1262.214402  359.932582  775.668711
# 2        766.215895      674.453726  1264.309018  359.932582  775.668711
# 3        766.197011      674.453726  1266.407109  359.932582  775.668711
# 4        766.178127      674.453726  1268.508683  359.932582  775.668711
#
# Country     ...      Western Sahara     Vietnam  Virgin Islands (U.S.)  \
# ...

# %% [markdown]
# #### Problem 2(b)
#
# Graphically display the distribution of income per person across all countries in the world for any given year (e.g. 2000).  What kind of plot would be best?

# %%
income.rename(columns={'index':'year'}, inplace=True)
#your code here
def yearPlot(year):
    yearFrame = income[(income.year==year)]
    yearFrame = yearFrame.transpose()
    yearFrame[0:].hist(bins=40)
    plt.xlabel('Per Capita Income, USD')
    plt.ylabel('Frequency')
    plt.title(year)
    plt.show()

for years in [2000, 2002, 2005, 2010]:
    yearPlot(years)

# %% [markdown]
# #### Problem 2(c)
#
# Write a function to merge the `countries` and `income` data sets for any given year.

# %%
"""
Function
--------
mergeByYear

Return a merged DataFrame containing the income, 
country name and region for a given year. 

Parameters
----------
year : int
    The year of interest

Returns
-------
a DataFrame
   A pandas DataFrame with three columns titled 
   'Country', 'Region', and 'Income'. 

Example
-------
>>> mergeByYear(2010)
"""


#your code here
def mergeByYear(year):
    cols = ['Country', year]
    yearFrame = inc[cols]
    return pd.merge(yearFrame, countries, on='Country')

mergeByYear(2000).head()
# Out:
#        Country          2000  Region
# 0  Afghanistan    663.909878    ASIA
# 1      Albania   4195.210368  EUROPE
# 2      Algeria   5098.853564  AFRICA
# 3      Andorra  30265.941054  EUROPE
# 4       Angola   2446.645873  AFRICA

# %% [markdown]
# #### Problem 2(d)
#
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution of the income per person by region data set from 2(c) for a given year. Describe how these change through the recent years?
#
# **Hint**: Use a `for` loop to consider multiple years.

# %%
#your code here
def regionHist(year):
    for region in ['ASIA', 'AFRICA','EUROPE','NORTH AMERICA','SOUTH AMERICA','OCEANIA']:
        working = mergeByYear(year)
        regional_region = working[(working.Region == region)]
        regional_region[year].hist(bins=20)
        plt.xlabel('Per Capita Income, USD')
        plt.ylabel('Frequency')
        plt.title(region + ", " + str(year))
        plt.show()
        



year = 2012
regionHist(year)

for year in range (1950,2012,10):
    working = mergeByYear(year)
    working.boxplot(year, by = 'Region')

# %% [markdown]
# ## Discussion for Problem 2
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
#
# The boxplots show changing income dynamics across 6 decades. The biggest changes in distributions seem to happen between 1970-1990. Asia has many extremely high outliers, possibly due to oil revenues in middle eastern countries. Europe consistently has the highest median income across the sample period, and its distribution widens significantly across the sample period. Asia exhibits consistent growth in the incomes of its middle 50%, while Africa remains very low accross time.

# %% [markdown]
# ## Problem 3
#
# In general, if group A has larger values than group B on average, does this mean the largest values are from group A? Discuss after completing each of the problems below.

# %% [markdown]
# #### Problem 3(a)
#
# Assume you have two list of numbers, X and Y, with distribution approximately normal. X and Y have standard deviation equal to 1, but the average of X is different from the average of Y.  If the difference in the average of X and the average of Y is larger than 0, how does the proportion of X > a compare to the proportion of Y > a?

# %% [markdown]
# Write a function that analytically calculates the ratio of these two proportions: Pr(X > a)/Pr(Y > a) as function of the difference in the average of X and the average of Y.
#
# **Hint**: Use the `scipy.stats` module for useful functions related to a normal random variable such as the probability density function, cumulative distribution function and survival function.
#
# **Update**: Assume Y is normally distributed with mean equal to 0.

# %% [markdown]
# Show the curve for different values of a (a = 2,3,4 and 5).

# %%
"""
Function
--------
ratioNormals

Return ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a) as function of 
    the difference in the average of X 
    and the average of Y. 

Parameters
----------
diff : difference in the average of X 
    and the average of Y. 
a : cutoff value

Returns
-------
Returns ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a)
    
Example
-------
>>> ratioNormals(diff = 1, a = 2)
"""
import scipy as sci
from scipy.stats import norm

# %%
#your code here
def ratioNormals(diff,a):
    pry = (1-norm.cdf(a))
    prx = (1 -norm.cdf(a-diff))
    return prx/pry
print ratioNormals(1,2)
print ratioNormals(1,3)


#your code here
astr = "a = "
for i in range(2,6):
    x = np.linspace(0,5,30)
    y = ratioNormals(x,i)
    plt.plot(x,y)
    plt.title(astr + str(i))
    plt.xlabel("difference in group averages")
    plt.ylabel("ratio : Pr(X > a)/Pr(Y > a)")
    plt.show()
# Out:
# 6.97381686809
# 16.853222551

# %% [markdown]
# #### Problem 3(b)
#
# Now consider the distribution of income per person from two regions: Asia and South America. Estimate the average income per person across the countries in those two regions. Which region has the larger average of income per person across the countries in that region?
#
# **Update**: Use the year 2012.

# %%
#your code here
year = 2012
yr2012 = mergeByYear(2012)
asia = yr2012[(yr2012.Region == ("ASIA"))]
africa = yr2012[(yr2012.Region == ("AFRICA"))]


asia.columns = ['country','income','region']
africa.columns = ['country','income','region']


print "Africa Avg. Per Capita Income, 2012: ",africa.mean().income
print "Asia Avg. Per Capita Income, 2012: ", asia.mean().income
print "Average per capita income in 2012 was higher in Asia than in Africa"
# Out:
# Africa Avg. Per Capita Income, 2012:  3673.28338767
# Asia Avg. Per Capita Income, 2012:  14510.0413832
# Average per capita income in 2012 was higher in Asia than in Africa

# %% [markdown]
# #### Problem 3(c)
#
# Calculate the proportion of countries with income per person that is greater than 10,000 dollars. Which region has a larger proportion of countries with income per person greater than 10,000 dollars? If the answer here is different from the answer in 3(b), explain why in light of your answer to 3(a).
#
# **Update**: Use the year 2012.

# %%
asiaHigh = asia[(asia.income > 10000)].shape[0]
asiaTot =  asia.shape[0]

africaHigh = africa[(africa.income > 10000)].shape[0]
africaTot = africa.shape[0]
#print asiaHigh,asiaTot,africaHigh,africaTot

print "Proportion of Asian countries where income per person is > $10,000: ", (float(asiaHigh)/float(asiaTot))*100,"%"
print "Proportion of African countries where income per person is > $10,000: ", (float(africaHigh)/float(africaTot))*100,"%"
# Out:
# Proportion of Asian countries where income per person is > $10,000:  36.8421052632 %
# Proportion of African countries where income per person is > $10,000:  10.2040816327 %

# %%
#your code here
print "If the per capita incomes across countries in these regions were normally distributed, we would expect the proportions to be as follows"
asiaMean = asia.mean().income 
asiaStd = asia.std().income
africaMean = africa.mean().income
africaStd = africa.std().income

zAfrica = (10000 - africaMean)/africaStd
zAsia = (10000 - asiaMean)/asiaStd

#Proportion of Asian countries where income per person is > $10,000
prAf = norm.sf(zAfrica)*100
#Proportion of African countries where income per person is > $10,000:
prAs = norm.sf(zAsia)*100

print prAf,"% ",prAs,"%"
# Out:
# If the per capita incomes across countries in these regions were normally distributed, we would expect the proportions to be as follows
# 7.04873850875 %  59.6373154227 %

# %% [markdown]
# #### Problem 3(d)
#
# **For AC209 Students**: Re-run this analysis in Problem 3 but compute the average income per person for each region, instead of the average of the reported incomes per person across countries in the region. Why are these two different? Hint: use this [data set](https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&gid=0).

# %%
#your code here

# %% [markdown]
# ## Discussion for Problem 3
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
# In this case, Asia has both a higher avg. per capita income and a higher proportion of countries with per capita income above $10,000, which makes sense and fits with our statistical estimation of the effect of group averages on the CDF of normally distributed variables. This can be shown in the plots following 3(a). As the averages diverge (x-axis increases) the proportion of values that meet the condition z>a increases.
